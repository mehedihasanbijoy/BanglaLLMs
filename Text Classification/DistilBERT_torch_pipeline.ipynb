# %% [markdown]
# <a href="https://colab.research.google.com/github/mehedihasanbijoy/BanglaLLMs/blob/main/Text%20Classification/DistilBERT_torch_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install Required Libraries

# %%
# %%capture

# !pip install -q gdown
# !pip install --upgrade transformers[torch]
# !pip install datasets

# %% [markdown]
# ## Download Necessary Corpora

# %%
# %%capture

# Download the folder named BLP2023-VITD (for fine-tune the LLM)
# !gdown "https://drive.google.com/drive/folders/1TqmhXN2hyLutFlSoVAyTWkBBIK_DaLuF?usp=sharing" --folder

# Fetch the corpus (for fine-tune the tokenizer)
# !gdown "https://drive.google.com/drive/folders/1oIT7DZhd4uXTpjgBeRGSP-Fs-1Ux3m-b?usp=sharing" --folder

# %%
# !unzip "/content/BLP2023-VITD/BLP2023-VITD.zip"
# Out:
# Archive:  /content/BLP2023-VITD/BLP2023-VITD.zip
# replace BLP2023-VITD/dev.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: BLP2023-VITD/dev.csv
#   inflating: BLP2023-VITD/test.csv
#   inflating: BLP2023-VITD/train.csv

# %% [markdown]
# ## Import Libraries

# %%
import torch
from datasets import Dataset
from transformers import Trainer, TrainingArguments, AutoTokenizer, BertForSequenceClassification, AdamW
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import random
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Ignore all warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fine-tune the Tokenizer

# %%
test = pd.read_csv("/content/BanglaParaphraseBUETNLP/test.csv")
train = pd.read_csv("/content/BanglaParaphraseBUETNLP/train.csv")
valid = pd.read_csv("/content/BanglaParaphraseBUETNLP/valid.csv")

df = pd.concat([test, train, valid], ignore_index=True)
df.reset_index(drop=True, inplace=True)

source_texts = df['source'].tolist()
target_texts = df['target'].tolist()
all_texts = source_texts + target_texts
# all_texts = all_texts[:500000]
all_texts[:3]
# Out:
# ['কিছুদিন আগে প্যারিস থেকে ঘুরে এসেছি।',
#  'ভাড়া করে ফেললেন কার্নেগি হলের মতো অত্যন্ত অভিজাত অডিটোরিয়াম, যেখানে হাজার হাজার মানুষ একসাথে বসে পারফর্মেন্স দেখতে পারে।',
#  'সম্পূর্ণ নিয়ন্ত্রণ হারিয়ে জাহাজ পড়লো ঘোর সমুদ্রে।']

# %%
all_considered_characters = [
    ' ',  'ঁ',  'ং',  'ঃ',  'অ',  'আ',  'ই',  'ঈ',  'উ',  'ঊ',  'ঋ',  'এ',  'ঐ',  'ও',  'ঔ',
    'ক',  'খ',  'গ',  'ঘ',  'ঙ',  'চ',  'ছ',  'জ',  'ঝ',  'ঞ',  'ট',  'ঠ',  'ড',  'ঢ',  'ণ',  'ত',
    'থ',  'দ',  'ধ',  'ন',  'প',  'ফ',  'ব',  'ভ',  'ম',  'য',  'র',  'ল',  'শ',  'ষ',  'স',  'হ',
    'ড়',   'ঢ়',   'য়',  '়',  'া',  'ি',  'ী',  'ু',  'ূ',  'ৃ',  'ে',  'ৈ',  'ো',  'ৌ',  '্',  'ৎ',
    '০',  '১',  '২',  '৩',  '৪',  '৫',  '৬',  '৭',  '৮',  '৯']

# %%
all_cleaned_sentences = []

for sent in tqdm(all_texts):
    cleaned_sent = ""
    for char in sent:
        if char in all_considered_characters:
            cleaned_sent += str(char)
    all_cleaned_sentences.append(cleaned_sent)
# Out:
# 100%|██████████| 933260/933260 [01:24<00:00, 11055.66it/s]

# %%
pretrained_tokenizer_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(pretrained_tokenizer_name)

example_sent = all_cleaned_sentences[random.randint(0, len(all_cleaned_sentences)-1)]

print(example_sent)
print(tokenizer.tokenize(example_sent))
print(tokenizer.encode(example_sent))
print(tokenizer.decode(tokenizer.encode(example_sent)))
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# তার সফলতার মূল কারণও এই দুটো প্রবাদ
# ['ত', '##া', '##র', '[UNK]', 'ম', '##ল', 'ক', '##া', '##র', '##ণ', '##ও', 'এ', '##ই', 'দ', '##ট', '##ে', '##া', 'প', '##র', '##ব', '##া', '##দ']
# [101, 1362, 29914, 29908, 100, 1370, 29909, 1353, 29914, 29908, 29897, 29888, 1351, 29885, 1364, 29895, 29917, 29914, 1367, 29908, 29904, 29914, 29900, 102]
# [CLS] তার [UNK] মল কারণও এই দটো পরবাদ [SEP]

# %%
# Customize training parameters
vocab_size = 30000
min_frequency = 5

# Fine-tune the tokenizer on your custom dataset
tokenizer_finetuned = tokenizer.train_new_from_iterator(np.array(all_cleaned_sentences).reshape(-1, 1), vocab_size=vocab_size)

print(example_sent)
print(tokenizer_finetuned.tokenize(example_sent))
print(tokenizer_finetuned.encode(example_sent))
print(tokenizer_finetuned.decode(tokenizer_finetuned.encode(example_sent)))
# Out:
# তার সফলতার মূল কারণও এই দুটো প্রবাদ
# ['তার', 'সফলতার', 'মল', 'কারণও', 'এই', 'দটো', 'পরবাদ']
# [2, 154, 7561, 550, 12569, 175, 1944, 14850, 3]
# [CLS] তার সফলতার মল কারণও এই দটো পরবাদ [SEP]

# %% [markdown]
# ## Process the Violence Inciting Text Detection (VITD) Corpus

# %%
train_df = pd.read_csv("/content/BLP2023-VITD/train.csv")
val_df = pd.read_csv("/content/BLP2023-VITD/dev.csv")
test_df = pd.read_csv("/content/BLP2023-VITD/test.csv")

print(f"Number of instances in training set  : {str(len(train_df)).rjust(4)}")
print(f"Number of instances in validation set: {str(len(val_df)).rjust(4)}")
print(f"Number of instances in Test set      : {str(len(test_df)).rjust(4)}")
# Out:
# Number of instances in training set  : 2700
# Number of instances in validation set: 1330
# Number of instances in Test set      : 2016

# %%
id2label = {0: "Non-Violence", 1: "Passive Violence", 2: "Direct Violence"}
print(f"id2label: {id2label}")

label2id = {v: k for k, v in id2label.items()}
print(f"label2id: {label2id}")
# Out:
# id2label: {0: 'Non-Violence', 1: 'Passive Violence', 2: 'Direct Violence'}
# label2id: {'Non-Violence': 0, 'Passive Violence': 1, 'Direct Violence': 2}

# %%
train_df.sample(3)
# Out:
#                                                    text  label
# 2180    ডাকাত জদি চোর কে বলে৷ ভালো হওয়ার কথা৷ কেমন লাগে      1
# 2288  ও কোন বিজ্ঞান মনস্ক লেখক নয়।সে একজন ইসলাম বিদ্...      1
# 2498                খুব সুন্দরতো এই ভিডিও ফুটেজ ধন্যবাদ      0

# %%
class CustomCorpus(torch.utils.data.Dataset):
    def __init__(self, df, tokenizer, max_len):
        self.df = df
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        text = self.df['text'].values[idx]
        ids_n_masks = self.tokenizer(
            text,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            pad_to_max_length=True,
            return_token_type_ids=True,
            truncation=True
        )
        return {
            "input_ids": torch.tensor(ids_n_masks["input_ids"], dtype=torch.long),
            "attention_mask": torch.tensor(ids_n_masks["attention_mask"], dtype=torch.long),
            "targets": torch.tensor(self.df["label"][idx], dtype=torch.long)
        }

# %%
max_len = 64
batch_size = 8

# %%
train_dataset = CustomCorpus(train_df, tokenizer_finetuned, max_len)
val_dataset = CustomCorpus(val_df, tokenizer_finetuned, max_len)
test_dataset = CustomCorpus(test_df, tokenizer_finetuned, max_len)

# %%
train_params = {'batch_size': batch_size,
                'shuffle': True,
                'num_workers': 0
                }

val_params = {'batch_size': batch_size,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': batch_size,
                'shuffle': True,
                'num_workers': 0
                }

# %%
training_loader = torch.utils.data.DataLoader(train_dataset, **train_params)
valid_loader = torch.utils.data.DataLoader(val_dataset, **train_params)
testing_loader = torch.utils.data.DataLoader(test_dataset, **test_params)

# %% [markdown]
# ## Fine-tune DistilBERT

# %%
n_classes = 3
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from transformers import DistilBertModel

class DistillBERTClass(torch.nn.Module):
    def __init__(self, n_classes):
        super(DistillBERTClass, self).__init__()
        self.l1 = DistilBertModel.from_pretrained("distilbert-base-uncased")
        self.pre_classifier = torch.nn.Linear(768, 768)
        self.dropout = torch.nn.Dropout(0.5)
        self.classifier = torch.nn.Linear(768, n_classes)

    def forward(self, input_ids, attention_mask):
        output_1 = self.l1(input_ids=input_ids, attention_mask=attention_mask)
        hidden_state = output_1[0]
        pooler = hidden_state[:, 0]
        pooler = self.pre_classifier(pooler)
        pooler = torch.nn.ReLU()(pooler)
        pooler = self.dropout(pooler)
        output = self.classifier(pooler)
        return output

# %%
model = DistillBERTClass(n_classes)
model
# Out:
# DistillBERTClass(
#   (l1): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
model.to(device)
print(f"Model is sent to {device}")
# Out:
# Model is sent to cuda

# %%
learning_rate = 2e-5

# %%
# Creating the loss function and optimizer
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params =  model.parameters(), lr=learning_rate)

# %%
# Function to calcuate the accuracy of the model
def calcuate_accu(big_idx, targets):
    n_correct = (big_idx==targets).sum().item()
    return n_correct

# %%
def train(epoch):
    tr_loss = 0
    n_correct = 0
    nb_tr_steps = 0
    nb_tr_examples = 0

    model.train()

    for data in training_loader:
        ids = data['input_ids'].to(device, dtype = torch.long)
        mask = data['attention_mask'].to(device, dtype = torch.long)
        targets = data['targets'].to(device, dtype = torch.long)
        # print(targets)

        outputs = model(ids, mask)
        # print(outputs)

        loss = loss_function(outputs, targets)
        tr_loss += loss.item()

        big_val, big_idx = torch.max(outputs.data, dim=1)
        # print(big_idx)
        n_correct += calcuate_accu(big_idx, targets)

        nb_tr_steps += 1
        nb_tr_examples+=targets.size(0)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = (n_correct*100)/nb_tr_examples
    print(f"Training Loss: {epoch_loss}, Training Accuracy: {epoch_accu:.2f}%")

    return

# %%
def valid(model, testing_loader):
    tr_loss = 0
    tr_loss = 0
    n_correct = 0
    nb_tr_steps = 0
    nb_tr_examples = 0
    model.eval()
    n_correct = 0; n_wrong = 0; total = 0
    with torch.no_grad():
        for data in testing_loader:
            ids = data['input_ids'].to(device, dtype = torch.long)
            mask = data['attention_mask'].to(device, dtype = torch.long)
            targets = data['targets'].to(device, dtype = torch.long)

            outputs = model(ids, mask).squeeze()

            loss = loss_function(outputs, targets)
            tr_loss += loss.item()

            big_val, big_idx = torch.max(outputs.data, dim=1)
            n_correct += calcuate_accu(big_idx, targets)

            nb_tr_steps += 1
            nb_tr_examples+=targets.size(0)

    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = (n_correct*100)/nb_tr_examples

    print(f"Validation Loss: {epoch_loss}, Validation Accuracy: {epoch_accu:.2f}%\n")

    return epoch_accu

# %%
num_epochs = 100
for epoch in range(num_epochs):
    print(f"Epoch {epoch+1} / {num_epochs}")
    train(epoch)
    valid(model, valid_loader)
# Out:
# Epoch 1 / 100
# Training Loss: 0.9719409841228519, Training Accuracy: 52.59%
# Validation Loss: 0.8665267080960873, Validation Accuracy: 61.50%
#
# Epoch 2 / 100
# Training Loss: 0.8395286760562976, Training Accuracy: 63.26%
# Validation Loss: 0.7910629211071722, Validation Accuracy: 66.02%
#
# Epoch 3 / 100
# Training Loss: 0.6440195577031762, Training Accuracy: 73.85%
# Validation Loss: 0.7615021033558304, Validation Accuracy: 68.05%
#
# Epoch 4 / 100
# Training Loss: 0.4203619236049391, Training Accuracy: 84.56%
# Validation Loss: 0.9003662662413305, Validation Accuracy: 66.92%
#
# Epoch 5 / 100
# Training Loss: 0.22802861262465546, Training Accuracy: 92.33%
# Validation Loss: 1.0077501360416234, Validation Accuracy: 67.22%
#
# Epoch 6 / 100
# Training Loss: 0.1262825116041232, Training Accuracy: 96.11%
# Validation Loss: 1.1174806339476637, Validation Accuracy: 65.79%
#
# Epoch 7 / 100
# Training Loss: 0.12811251309667246, Training Accuracy: 95.67%
# Validation Loss: 1.2070014768999493, Validation Accuracy: 67.74%
#
# Validation Loss: 2.4121916103123184, Validation Accuracy: 67.97%
#
# Epoch 48 / 100
# Training Loss: 0.0080571370241999, Training Accuracy: 99.78%
# Validation Loss: 2.09771889733488, Validation Accuracy: 65.56%
#
# Epoch 49 / 100
# Training Loss: 0.036095618438771696, Training Accuracy: 99.19%
# Validation Loss: 2.0366056259271192, Validation Accuracy: 67.74%
#
# Epoch 50 / 100
# Training Loss: 0.01752442251948804, Training Accuracy: 99.59%
# Validation Loss: 1.733128391153285, Validation Accuracy: 67.29%
#
# Epoch 51 / 100
# Training Loss: 0.006511054544539305, Training Accuracy: 99.78%
# Validation Loss: 2.0739343562742003, Validation Accuracy: 69.10%
#
# Epoch 52 / 100
# Training Loss: 0.00374250193987775, Training Accuracy: 99.93%
# Validation Loss: 2.19912506640062, Validation Accuracy: 68.72%
#
# Epoch 53 / 100
# Training Loss: 0.004129100270952841, Training Accuracy: 99.93%
# Validation Loss: 2.0498649699213143, Validation Accuracy: 68.72%
#
# Epoch 54 / 100
# Training Loss: 0.010198102738253962, Training Accuracy: 99.70%
# Validation Loss: 2.238913573939869, Validation Accuracy: 67.14%
#
# Epoch 55 / 100
# Training Loss: 0.008907637153269738, Training Accuracy: 99.70%
# Validation Loss: 2.3260779563103338, Validation Accuracy: 68.27%
#
# Epoch 56 / 100
# Training Loss: 0.0027805875569781578, Training Accuracy: 99.89%
# Validation Loss: 2.6523893739649793, Validation Accuracy: 67.97%
#
# Epoch 57 / 100
# Training Loss: 0.005424783612074834, Training Accuracy: 99.93%
# Validation Loss: 2.147346344893368, Validation Accuracy: 69.32%
#
# Epoch 58 / 100
# Training Loss: 0.011695928970847268, Training Accuracy: 99.81%
# Validation Loss: 1.9159712311213113, Validation Accuracy: 68.72%
#
# Epoch 59 / 100
# Training Loss: 0.0032925091310067652, Training Accuracy: 99.85%
# Validation Loss: 2.50040844479384, Validation Accuracy: 68.35%
#
# Epoch 60 / 100
# Training Loss: 0.00017729586102043022, Training Accuracy: 100.00%
# Validation Loss: 2.6314891310996713, Validation Accuracy: 68.27%
#
# Epoch 61 / 100
# Training Loss: 0.015692251254658268, Training Accuracy: 99.59%
# Validation Loss: 1.992212985551011, Validation Accuracy: 67.67%
#
# Epoch 62 / 100
# Training Loss: 0.009417500767957408, Training Accuracy: 99.78%
# Validation Loss: 2.0587946766496685, Validation Accuracy: 68.50%
#
# Epoch 63 / 100
# Training Loss: 0.0022132682846584635, Training Accuracy: 99.93%
# Validation Loss: 2.257201437614999, Validation Accuracy: 68.72%
#
# Epoch 64 / 100
# Training Loss: 0.0043243881415984484, Training Accuracy: 99.85%
# Validation Loss: 2.2240462232160474, Validation Accuracy: 69.85%
#
# Epoch 65 / 100
# Training Loss: 0.0015003450733936743, Training Accuracy: 99.93%
# Validation Loss: 2.336394213838176, Validation Accuracy: 69.70%
#
# Epoch 66 / 100
# Training Loss: 0.000152197866612923, Training Accuracy: 100.00%
# Validation Loss: 2.467304605042334, Validation Accuracy: 69.92%
#
# Epoch 67 / 100
# Training Loss: 6.744835793906747e-05, Training Accuracy: 100.00%
# Validation Loss: 2.5511573873009072, Validation Accuracy: 69.25%
#
# Epoch 68 / 100
# Training Loss: 3.071365245650345e-05, Training Accuracy: 100.00%
# Validation Loss: 2.6311232189428355, Validation Accuracy: 69.25%
#
# Epoch 69 / 100
# Training Loss: 2.769324090253221e-05, Training Accuracy: 100.00%
# Validation Loss: 2.6550160466586648, Validation Accuracy: 69.70%
#
# Epoch 70 / 100
# Training Loss: 3.757601690030829e-05, Training Accuracy: 100.00%
# Validation Loss: 2.7292526074271732, Validation Accuracy: 69.62%
#
# Epoch 71 / 100
# Training Loss: 2.2997957215484993e-05, Training Accuracy: 100.00%
# Validation Loss: 2.766952331213475, Validation Accuracy: 69.62%
#
# Epoch 72 / 100
# Training Loss: 6.63673797313773e-05, Training Accuracy: 100.00%
# Validation Loss: 2.8965387698299665, Validation Accuracy: 69.32%
#
# Epoch 73 / 100
# Training Loss: 0.04918065153104519, Training Accuracy: 98.78%
# Validation Loss: 1.6516017720805938, Validation Accuracy: 69.17%
#
# Epoch 74 / 100
# Training Loss: 0.014247522786058788, Training Accuracy: 99.63%
# Validation Loss: 2.006252066564344, Validation Accuracy: 69.25%
#
# Epoch 75 / 100
# Training Loss: 0.0021588323538762025, Training Accuracy: 99.89%
# Validation Loss: 2.336392141528618, Validation Accuracy: 70.15%
#
# Epoch 76 / 100
# Training Loss: 0.007318000703003371, Training Accuracy: 99.78%
# Validation Loss: 1.858597687225298, Validation Accuracy: 68.27%
#
# Epoch 77 / 100
# Training Loss: 0.0105832663403553, Training Accuracy: 99.74%
# Validation Loss: 2.2002581553256575, Validation Accuracy: 69.85%
#
# Epoch 78 / 100
# Training Loss: 0.0016533384613058202, Training Accuracy: 99.93%
# Validation Loss: 2.5692560217167975, Validation Accuracy: 69.47%
#
# Epoch 79 / 100
# Training Loss: 0.002945022170140163, Training Accuracy: 99.96%
# Validation Loss: 2.406378460899874, Validation Accuracy: 68.95%
#
# Epoch 80 / 100
# Training Loss: 0.00029412404278203875, Training Accuracy: 100.00%
# Validation Loss: 2.541630812117715, Validation Accuracy: 69.17%
#
# Epoch 81 / 100
# Training Loss: 0.00040024662226755263, Training Accuracy: 100.00%
# Validation Loss: 2.7660780069313686, Validation Accuracy: 67.44%
#
# Epoch 82 / 100
# Training Loss: 0.017830398586259774, Training Accuracy: 99.59%
# Validation Loss: 2.280529135525851, Validation Accuracy: 66.92%
#
# Epoch 83 / 100
# Training Loss: 0.0009937883845629945, Training Accuracy: 100.00%
# Validation Loss: 2.6888839958204382, Validation Accuracy: 67.74%
#
# Epoch 84 / 100
# Training Loss: 0.000793251525021182, Training Accuracy: 99.96%
# Validation Loss: 2.6231010231998892, Validation Accuracy: 69.17%
#
# Epoch 85 / 100
# Training Loss: 0.0007689143550472305, Training Accuracy: 99.96%
# Validation Loss: 3.0749162748637584, Validation Accuracy: 67.22%
#
# Epoch 86 / 100
# Training Loss: 0.00019793084020582242, Training Accuracy: 100.00%
# Validation Loss: 2.8038174533591325, Validation Accuracy: 69.47%
#
# Epoch 87 / 100
# Training Loss: 3.260983588009329e-05, Training Accuracy: 100.00%
# Validation Loss: 2.8717099515866806, Validation Accuracy: 69.47%
#
# Epoch 88 / 100
# Training Loss: 0.008562976997686128, Training Accuracy: 99.81%
# Validation Loss: 2.428656382997981, Validation Accuracy: 68.80%
#
# Epoch 89 / 100
# Training Loss: 0.01004010163552056, Training Accuracy: 99.81%
# Validation Loss: 2.082292199289931, Validation Accuracy: 68.87%
#
# Epoch 90 / 100
# Training Loss: 0.018834570477279076, Training Accuracy: 99.48%
# Validation Loss: 2.035900727382398, Validation Accuracy: 70.68%
#
# Epoch 91 / 100
# Training Loss: 0.002152730591493826, Training Accuracy: 99.96%
# Validation Loss: 2.4092376417210546, Validation Accuracy: 69.47%
#
# Epoch 92 / 100
# Training Loss: 0.004658449261009641, Training Accuracy: 99.93%
# Validation Loss: 2.1960023792117154, Validation Accuracy: 71.35%
#
# Epoch 93 / 100
# Training Loss: 0.0006594874122887922, Training Accuracy: 99.96%
# Validation Loss: 2.3948417090843557, Validation Accuracy: 70.60%
#
# Epoch 94 / 100
# Training Loss: 0.00020440770411842742, Training Accuracy: 100.00%
# Validation Loss: 2.514092074081538, Validation Accuracy: 70.90%
#
# Epoch 95 / 100
# Training Loss: 0.00010663002999186014, Training Accuracy: 100.00%
# Validation Loss: 2.691580662766797, Validation Accuracy: 70.60%
#
# Epoch 96 / 100
# Training Loss: 0.012988285056761112, Training Accuracy: 99.85%
# Validation Loss: 1.9363487410236395, Validation Accuracy: 69.85%
#
# Epoch 97 / 100
# Training Loss: 0.009304555880110796, Training Accuracy: 99.85%
# Validation Loss: 1.8367701336604816, Validation Accuracy: 69.85%
#
# Epoch 98 / 100
# Training Loss: 0.004122716485556785, Training Accuracy: 99.89%
# Validation Loss: 2.3948135844772613, Validation Accuracy: 70.15%
#
# Epoch 99 / 100
# Training Loss: 0.005077488655829445, Training Accuracy: 99.96%
# Validation Loss: 2.4816528138288345, Validation Accuracy: 70.15%
#
# Epoch 100 / 100
# Training Loss: 0.015416028584426514, Training Accuracy: 99.70%
# Validation Loss: 2.629447506192596, Validation Accuracy: 69.47%

# %%
acc = valid(model, testing_loader)
print("Accuracy on test data = %0.2f%%" % acc)
# Out:
# Validation Loss: 2.7520335344535334, Validation Accuracy: 67.36%
#
# Accuracy on test data = 67.36%

# %%
def violence_identifier(sentence):
    input_tokens = tokenizer_finetuned(sentence, return_tensors="pt", padding=True, truncation=True)
    input_tokens = {key: value.to(device) for key, value in input_tokens.items()}

    outputs = model(**input_tokens)
    big_val, big_idx = torch.max(outputs.data, dim=1)

    print(f"{'*'*50}\nSentence  : {test_example}\nPrediction: {id2label[big_idx.item()]}\n{'*'*50}")

# %%
# Example sentence
test_example = "কুত্তার বাচ্চা দেখতে শুয়োরের বাচ্চার থেকে সুন্দর।"

violence_identifier(test_example)
# Out:
# **************************************************
# Sentence  : কুত্তার বাচ্চা দেখতে শুয়োরের বাচ্চার থেকে সুন্দর।
# Prediction: Passive Violence
# **************************************************
